# %% [markdown]
# ## **Pandas **

# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
pd.Series([7,45,9,'Mmd',86,93,np.nan,-34])
# Out:
# 0      7
# 1     45
# 2      9
# 3    Mmd
# 4     86
# 5     93
# 6    NaN
# 7    -34
# dtype: object

# %%
dates = pd.date_range("20220203",periods=4)
dates
# Out:
# DatetimeIndex(['2022-02-03', '2022-02-04', '2022-02-05', '2022-02-06'], dtype='datetime64[ns]', freq='D')

# %%
np.random.randn(6,4) #Choose random numbers from normal distribution
# Out:
# array([[-0.11634817, -1.00756611,  0.7411302 , -0.57683398],
#        [ 0.1927497 ,  1.02706573, -0.5396588 ,  0.67193438],
#        [-0.19144326,  1.42827286,  1.1847392 , -0.88052682],
#        [-0.82117308, -0.04914467, -0.51394733, -1.71349361],
#        [-0.56391863, -0.00991141, -0.71026912,  0.29831613],
#        [ 0.54410963, -1.28285782, -0.65407923, -0.2695932 ]])

# %%
np.random.rand(6,4) #Choose a random number between 0 and 1
# Out:
# array([[0.16391357, 0.46040597, 0.15382389, 0.02427499],
#        [0.14924754, 0.80572047, 0.53939525, 0.48695706],
#        [0.64720303, 0.21202609, 0.53151996, 0.3016516 ],
#        [0.81941921, 0.91830124, 0.42002096, 0.58721074],
#        [0.15339044, 0.19669039, 0.14945952, 0.45635555],
#        [0.21309567, 0.6753204 , 0.911153  , 0.63853942]])

# %%
df = pd.DataFrame(np.random.randn(4,4),index=dates,columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2022-02-03 -0.598460 -0.577292 -1.994071 -0.544164
# 2022-02-04 -0.853117 -0.827539  0.241006 -1.375300
# 2022-02-05  1.127518 -0.539047 -3.510151 -1.387846
# 2022-02-06  1.141664 -0.552745  0.081349  0.502837

# %% [markdown]
# ## **Doing some interesting actions on Data Frame** ⌨

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df.A
# Out:
# 2022-02-03   -0.544164
# 2022-02-04   -1.375300
# 2022-02-05   -1.387846
# 2022-02-06    0.502837
# Freq: D, Name: D, dtype: float64

# %%
df.head(1)
# Out:
#                   A         B         C         D
# 2022-02-03 -0.59846 -0.577292 -1.994071 -0.544164

# %%
df.head(3) #It shows the numbers of line of the top of data frame
# Out:
#                    A         B         C         D
# 2022-02-03 -0.598460 -0.577292 -1.994071 -0.544164
# 2022-02-04 -0.853117 -0.827539  0.241006 -1.375300
# 2022-02-05  1.127518 -0.539047 -3.510151 -1.387846

# %%
df.tail(2) #It shows the numbers of line of the bottom of data frame
# Out:
#                    A         B         C         D
# 2022-02-05  1.127518 -0.539047 -3.510151 -1.387846
# 2022-02-06  1.141664 -0.552745  0.081349  0.502837

# %%
df.describe()  # It shows a summary of data (Something cool!!! I guess)
# Out:
#               A         B         C         D
# count  4.000000  4.000000  4.000000  4.000000
# mean   0.204401 -0.624156 -1.295467 -0.701118
# std    1.079126  0.136509  1.793437  0.894475
# min   -0.853117 -0.827539 -3.510151 -1.387846
# 25%   -0.662125 -0.639854 -2.373091 -1.378436
# 50%    0.264529 -0.565019 -0.956361 -0.959732
# 75%    1.131055 -0.549321  0.121263 -0.282414
# max    1.141664 -0.539047  0.241006  0.502837

# %%
df.mean()
# Out:
# A    0.204401
# B   -0.624156
# C   -1.295467
# D   -0.701118
# dtype: float64

# %%
df.std()
# Out:
# A    1.079126
# B    0.136509
# C    1.793437
# D    0.894475
# dtype: float64

# %%
df["B"].mean()
# Out:
# -0.6241558794006593

# %%
df[0:2]
# Out:
#                    A         B         C         D
# 2022-02-03 -0.598460 -0.577292 -1.994071 -0.544164
# 2022-02-04 -0.853117 -0.827539  0.241006 -1.375300

# %%
df.T
# Out:
#    2022-02-03  2022-02-04  2022-02-05  2022-02-06
# A   -0.598460   -0.853117    1.127518    1.141664
# B   -0.577292   -0.827539   -0.539047   -0.552745
# C   -1.994071    0.241006   -3.510151    0.081349
# D   -0.544164   -1.375300   -1.387846    0.502837

# %%
df.sort_values(by = "B") # It sort the data according to the value of  B , so changes all the data frame
# Out:
#                    A         B         C         D
# 2022-02-04 -0.853117 -0.827539  0.241006 -1.375300
# 2022-02-03 -0.598460 -0.577292 -1.994071 -0.544164
# 2022-02-06  1.141664 -0.552745  0.081349  0.502837
# 2022-02-05  1.127518 -0.539047 -3.510151 -1.387846

# %%
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2022-02-05  1.127518 -0.539047 -3.510151 -1.387846
# 2022-02-06  1.141664 -0.552745  0.081349  0.502837

# %%
from google.colab import drive
drive.mount('drive')
df.to_csv('data.csv')
# !cp data.csv "drive/My Drive/"
# Out:
# Mounted at drive
