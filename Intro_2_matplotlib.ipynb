# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
plt.plot([1 , 3 , 4,52 ],[-2 ,97 , -9,193],'r+-')

# %%
t = np.arange(0,5,0.2)
plt.plot(t,t**2,'r-.',t,t,"bs",t,t**3,"g-o")
# Out:
# [<matplotlib.lines.Line2D at 0x7a68541a3190>,
#  <matplotlib.lines.Line2D at 0x7a68541a3160>,
#  <matplotlib.lines.Line2D at 0x7a68541a32e0>]

# %%
data = {'a' : np.arange(500) ,
        'b' : np.random.randint(0,50,50),
        'c' : np.random.randn(500)
        }
plt.scatter(data['a'],data['c'])
